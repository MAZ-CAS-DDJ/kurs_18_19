# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import json
import csv
import re

# %%
s = webdriver.Chrome('/usr/local/bin/chromedriver')

# %% [markdown]
# https://selenium-python.readthedocs.io/api.html#selenium.webdriver.remote.webdriver.WebDriver.find_element_by_link_text-

# %%
USERNAME = "#####@###.ch"
PASSWORD = "####"
MY_SLUG = "###.###"

# %%
def login(s):
    try:
        print("Logging into FB")
        s.get("http://facebook.com/login")
        s.find_element_by_id("email").send_keys(USERNAME)
        r = s.find_element_by_id("pass")
        r.send_keys(PASSWORD)
        r.send_keys(Keys.RETURN)
    except:
        print("Probably already logged in...")

# %%
def scrape_friends(s):
    login(s)
    #Scrape my friends
    s.get("https://www.facebook.com/%s/friends" % MY_SLUG)
    for i in range(30):
        print("scrolling...and...waiting..%s" % i)
        s.execute_script('window.scroll(0,100000);')
        time.sleep(1)
    # get html
    elem = s.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    soup = BeautifulSoup(source_code, 'lxml')
    friends = soup.select(".fcb a")
    print("Scraping {%s} friends" % len(friends))
    with open('friends.csv', mode='w') as myfile:
        mycsv = csv.writer(myfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        mycsv.writerow(["Friend ID", "Friend Name"])
        for friend in friends:
          try:
            friend_name = friend.text.encode("ascii","ignore")
            friend_id = json.loads(friend["data-gt"])["engagement"]["eng_tid"].encode("ascii","ignore")
            mycsv.writerow([friend_id, friend_name])
          except:
            print("Problems obtaining %s" % friend)

# %%
scrape_friends(s)
# Out:
# Logging into FB
# Probably already logged in...
# scrolling...and...waiting..0
# scrolling...and...waiting..1
# scrolling...and...waiting..2
# scrolling...and...waiting..3
# scrolling...and...waiting..4
# scrolling...and...waiting..5
# scrolling...and...waiting..6
# scrolling...and...waiting..7
# scrolling...and...waiting..8
# scrolling...and...waiting..9
# scrolling...and...waiting..10
# scrolling...and...waiting..11
# scrolling...and...waiting..12
# scrolling...and...waiting..13
# scrolling...and...waiting..14
# scrolling...and...waiting..15
# scrolling...and...waiting..16
# scrolling...and...waiting..17
# scrolling...and...waiting..18
# scrolling...and...waiting..19
# scrolling...and...waiting..20
# scrolling...and...waiting..21
# scrolling...and...waiting..22
# scrolling...and...waiting..23
# scrolling...and...waiting..24
# scrolling...and...waiting..25
# scrolling...and...waiting..26
# scrolling...and...waiting..27
# scrolling...and...waiting..28
# scrolling...and...waiting..29
# Scraping {296} friends
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100003788497361" href="#" rel="dialog" role="button">Suzi Taylor</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100002472387897" href="#" rel="dialog" role="button">Ahmed Fouad</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100001193119832" href="#" rel="dialog" role="button">Ja Nine</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100001021377936" href="#" rel="dialog" role="button">Sven Berg</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=1656431279" href="#" rel="dialog" role="button">Ann Früchtl</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=1207602781" href="#" rel="dialog" role="button">Simon Setzer</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=692063906" href="#" rel="dialog" role="button">Suzi Taylor</a>
# Problems obtaining <a ajaxify="/ajax/friends/inactive/dialog?id=100002630559037" href="#" rel="dialog" role="button">Cornelia Stietz</a>
# Problems obtaining <a data-hovercard="/ajax/hovercard/page.php?id=194911435334&amp;extragetparams=%7B%22__tn__%22%3A%22%2Cd-k-R%22%2C%22eid%22%3A%22
# %%
def scrape_mutual_friends(s):
    login(s)
    edgelist = []
    friendslist = []
    
    #Get FriendsIDs
    with open('friends.csv', mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for i, row in enumerate(csv_reader):
            if i != 0:
                friendslist.append([row["Friend ID"],row["Friend Name"]])
                
    #Get my Id
    s.get("http://facebook.com/%s" % MY_SLUG)
    elem = s.find_element_by_xpath("//*")
    source_code = elem.get_attribute("outerHTML")
    soup = BeautifulSoup(source_code, 'lxml')
    my_id = re.search(r"profile_id=(\d*)", source_code).groups()[0]
    print("My ID: %s" % my_id)

    for friends in friendslist:
        print("Visiting friend: %s" % friends[1])
        s.get("https://www.facebook.com/browse/mutual_friends/?uid=%s&node=%s" % (my_id,friends[0]))
        elem = s.find_element_by_xpath("//*")
        source_code = elem.get_attribute("outerHTML")
        soup = BeautifulSoup(source_code, 'lxml')
        mutual_friends = soup.select(".fcb a")
        print("Found %s mutual friends" % len(mutual_friends))
        for friend in mutual_friends:
            edgelist.append([friends[0],json.loads(friend["data-gt"])["engagement"]["eng_tid"].encode("ascii","ignore")])

    with open('network.csv', mode='w') as myfile:
        mycsv = csv.writer(myfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        mycsv.writerow(["From","To"])
        for edge in edgelist:
            mycsv.writerow([edge[0],edge[1]])

# %%
scrape_mutual_friends(s)
# Out:
# Logging into FB
# Probably already logged in...
# My ID: 671975471
# Visiting friend: Margarethe Plotkowiak
# Found 29 mutual friends
# Visiting friend: Andreas Heim
# Found 25 mutual friends
# Visiting friend: Szymon Sobik
# Found 7 mutual friends
# Visiting friend: Daniel Koelsch
# Found 27 mutual friends
# Visiting friend: Amanda Mickley-Gass
# Found 2 mutual friends
# Visiting friend: Jan Suess
# Found 30 mutual friends
# Visiting friend: David William Mcgarvey
# Found 6 mutual friends
# Visiting friend: Silke Leisentritt
# Found 16 mutual friends
# Visiting friend: Julian Fleig
# Found 25 mutual friends
# Visiting friend: Wolfgang Steitz
# Found 29 mutual friends
# Visiting friend: Anja Hanschke
# Found 2 mutual friends
# Visiting friend: Jrme Kommer
# Found 26 mutual friends
# Visiting friend: Oliver Price
# Found 1 mutual friends
# Visiting friend: Maria Kuwilsky
# Found 23 mutual friends
# Visiting friend: Katherine Schn
# Found 16 mutual friends
# Visiting friend: Corinne Schweizer
# Found 11 mutual friends
# Visiting friend: Esther Federspiel
# Found 0 mutual friends
# Visiting friend: Oliver Gass
# Found 9 mutual friends
# Visiting friend: Manisha Shaikh
# Found 6 mutual friends
# Visiting friend: Lawrence McGrath
# Found 2 mutual friends
# Visiting friend: Saerom Yoon
# Found 26 mutual friends
# Visiting friend: Basheer Ahmed
# Found 4 mutual friends
# Visiting friend: Urszula Sobik
# Found 4 mutual friends
# Visiting friend: Martin Hermida
# Found 10 mutual friends
# Visiting friend: Silje Kristiansen
# Visiting friend: Sarah Bright
# Found 14 mutual friends
# Visiting friend: Tracy Liu
# Found 5 mutual friends
# Visiting friend: Caroline Riggs
# Found 1 mutual friends
# Visiting friend: Thomas Engenhorst
# Found 24 mutual friends
# Visiting friend: Negar Rajabi
# Found 21 mutual friends
# Visiting friend: Gregory Brzozowski
# Found 2 mutual friends
# Visiting friend: Joel Odesser
# Found 9 mutual friends
# Visiting friend: Yut Mun
# Found 11 mutual friends
# Visiting friend: Khwanyo Bu
# Found 2 mutual friends
# Visiting friend: Andri Hinnen
# Found 2 mutual friends
# Visiting friend: Tamsyn Jefferson-Harvey
# Found 2 mutual friends
# Visiting friend: Niko Bender
# Found 4 mutual friends
# Visiting friend: Heiko Walz
# Found 8 mutual friends
# Visiting friend: Stephanie Rhein
# Found 30 mutual friends
# Visiting friend: Christian Brumm
# Found 19 mutual friends
# Visiting friend: Cornelius Rabsch
# Found 4 mutual friends
# Visiting friend: Krzysztof Hebel
# Found 0 mutual friends
# Visiting friend: Nicole Smith
# Found 10 mutual friends
# Visiting friend: Carissa Sirikit
# Found 2 mutual friends
# Visiting friend: Daniel Lokshtanov
# Found 7 mutual friends
# Visiting friend: Moe Furui
# Found 13 mutual friends
# Visiting friend: Catalin Andrei
# Found 21 mutual friends
# Visiting friend: Amber Leigh Griffioen
# Found 0 mutual friends
# Visiting friend: Malte Probst
# Found 11 mutual friends
# Visiting friend: Farina Saiyed
# Found 4 mutual friends
# Visiting friend: Eric Funk
# Found 2 mutual friends
# Visiting friend: Eva Rttinger
# Found 8 mutual friends
# Visiting friend: Paul Klement
# Found 3 mutual friends
# Visiting friend: Sabine Kirsch
# Found 10 mutual friends
# Visiting friend: Zara Weinberger
# Found 26 mutual friends
# Visiting friend: Sebastian Seitz
# Found 4 mutual friends
# Visiting friend: Nadine Hau
# Found 6 mutual friends
# Visiting friend: Sebastian Fahrenkrog
# Found 2 mutual friends
# Visiting friend: Roland Gruschka
# Found 2 mutual friends
# Visiting friend: Christian Borth
# Found 5 mutual friends
# Visiting friend: Phil Liip
# Found 1 mutual friends
# Visiting friend: Katja Hitz
# Found 4 mutual friends
# Visiting friend: Josefine Alarich
# Found 1 mutual friends
# Visiting friend: Andi Hss R
# Found 9 mutual friends
# Visiting friend: Dia Na
# Found 1 mutual friends
# Visiting friend: Berd Schlchter
# Found 3 mutual friends
# Visiting friend: Terry Gregory
# Found 2 mutual friends
# Visiting friend: Mariusz Karbowski
# Found 0 mutual friends

# %%
import networkx as nx

def create_user_network():
    friendslist = []
    edgelist = []
    
    with open('friends.csv', mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for i, row in enumerate(csv_reader):
            if i != 0:
                friendslist.append([row["Friend ID"],row["Friend Name"]])        

    with open('network.csv', mode='r') as csv_file:
        csv_reader = csv.DictReader(csv_file)
        for i, row in enumerate(csv_reader):
            if i != 0:
                edgelist.append([row["From"],row["To"]])
    
    G  = nx.Graph(name="Friends")
                            
    for friend in friendslist:
        G.add_node(friend[0],label=friend[1], size=1)

    for edge in edgelist:
        G.add_edge(edge[0],edge[1],weight=1)
   
    nx.write_gexf(G,"Friends.gexf")

# %%
create_user_network()
