# %% [markdown]
# # APIs und Authentifikation (Google API)

# %% [markdown]
# Gestern haben wir uns die Erdbeben-Applikation angeschaut. Die Nutzung ist zwar begrenzt, doch es für deren Nutzung keine weitere Zulassung notwendig. Das ist bei den meisten anderen APIs nicht der Fall. In der Regel verlangen die Besitzer einer API Authentifikation der Nutzer. So können sie kontrollieren, wer wieviel nutzt. Denn auch eine API-Abfrage beansprucht Rechenkraft. Bei Millionen Abfragen kann das schnell ins Geld gehen. Es gibt dabei verschiedene API-Typen: REST, SOAP, XML-RCP oder JSON-RPC. Was die verschiedenen Vorteile dieser API-Technologien sind, schlägt ihr am besten nach. Die gängigsten sind heute REST und SOAP. Die trifft man immer wieder.

# %% [markdown]
# Wie man sich authentifiziert, wollen wir uns nun gemeinsam anschauen. Wir tun das mit der Google Maps API. Zu allererst müssen wir eine Key kreieren. Dafür brauchen wir eine Gmail-Konto und eine Kreditkarte. Wir werden keinen Rappen ausgeben, die erste 100'000 Aufrufe sind gratis. Die Kreditkarte ist trotzdem nötig. Als erstes besuchen wir [also die Google-Maps-Plattform](https://cloud.google.com/maps-platform).

# %% [markdown]
# ## Die Google API
# Die API kann man für verschiedene Sachen verwenden: Um Distanzen zu berechnen, um Standorte mit Geo-Daten auszustatten, oder um Standorte zu suchen. Natürlich nicht einzelne Standorte, sondern ganz viele. In diesem Beispiel werden wir uns bestimmte Standorte suchen.

# %% [markdown]
# Nachdem ihr Euch oben bei Google angemeldet habt, müsst ihr eine API Key generieren und abspeichern. Nun gehen wir nur Places API und Places Search. Das [ist hier](https://developers.google.com/places/web-service/intro).

# %% [markdown]
# ### Das italienische Restaurant mit den meisten Sternen bei Google Maps?

# %% [markdown]
# Wir werden mir der Textsearch-Option arbeiten: ```https://maps.googleapis.com/maps/api/place/textsearch/output?parameters```. Wir geben ein:
# - https://maps.googleapis.com/maps/api/place/textsearch/json
# - query=italienische+restaurants+in+zurich
# - fields=formatted_address,name,rating,opening_hours,pagetoken
# - key=XXXXXX

# %%
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+zurich&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
key = "key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&"

# %%
api_query = url+query+fields+key

# %% [markdown]
# importieren wir requests

# %%
import requests

# %%
r = requests.get(api_query)
result = r.json()

# %%
len(result)
# Out:
# 4

# %%
for key in result:
    print(key)
# Out:
# results
# next_page_token
# status
# html_attributions

# %%
result['results'][0]
# Out:
# {'formatted_address': 'Am Münsterhof, Waaggasse 7, 8001 Zürich, Switzerland',
#  'geometry': {'location': {'lat': 47.3701154, 'lng': 8.5402376},
#   'viewport': {'northeast': {'lat': 47.37144292989273,
#     'lng': 8.541555679892724},
#    'southwest': {'lat': 47.36874327010729, 'lng': 8.53885602010728}}},
#  'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#  'id': '5d645a5841434d1842e1197430d4e276187ecd7b',
#  'name': 'Ristorante Orsini',
#  'opening_hours': {'open_now': False},
#  'photos': [{'height': 1536,
#    'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104665277575624540283/photos">A Google User</a>'],
#    'photo_reference': 'CmRaAAAAbkak5MCBiW--l4E5WXo29pRCb-0s07hfM4BjHhBRhPjKvrvQv32-0ed2Dy8P-Gp1Sqsk6twI_tgzBspsJqbYvQ53mOF4rUY3_vzftKtjZUjWm0S1ZEB60kUZKtyIStUQEhCGAcL-NKv8rCsePXGuN3EXGhQ-STZWAIGoPcQ3sZfN66WDQe3JAw',
#    'width': 2048}],
#  'place_id': 'ChIJDc2DkwAKkEcRR6BfM4Jl9Bc',
#  'plus_code': {'compound_code': '9GCR+23 Zürich, Switzerland',
#   'global_code': '8FVC9GCR+23'},
#  'rating': 4.6,
#  'reference': 'CmRbAAAAo0fgVQ1mMMtcldzQz1ZfoAIxOUV9-3pbATqIPJGxQu-H2Wpsk4IIaRZPNUvdWlav9oiOII8JcqcRbOIEkyPUFVfHHmm2L4gxBQzdhba4g-gtP7fav--PSREvpTqG7wyCEhDwGLujWpXuUhZRUHfAZz9XGhQlxiaDkywW53SAj09NQTb9WdvfUg',
#  'types': ['restaurant', 'food', 'point_of_interest', 'establishment']}

# %%
new_lst = []

for elem in result['results']:
    address = elem['formatted_address']
    name = elem['name']
    rating = elem['rating']
    
    mini_dict = {'Addresse': address, 
                 'Name': name,
                 'Rating': rating}
    
    new_lst.append(mini_dict)

# %%
import pandas as pd

# %%
pd.DataFrame(new_lst)
# Out:
#                                              Addresse                  Name  \
# 0   Am Münsterhof, Waaggasse 7, 8001 Zürich, Switz...     Ristorante Orsini
# 1      Niederdorfstrasse 80, 8001 Zürich, Switzerland              La Pasta
# 2        Badenerstrasse 275, 8003 Zürich, Switzerland     Taverne da Angelo
# 3           Nordstrasse 182, 8037 Zürich, Switzerland          Tre Fratelli
# 4           Hohlstrasse 449, 8048 Zürich, Switzerland             Da Angela
# 5         Gertrudstrasse 37, 8003 Zürich, Switzerland       Da Michelangelo
# 6        Augustinergasse 25, 8001 Zürich, Switzerland   Cantinetta Antinori
# 7             Spitalgasse 5, 8001 Zürich, Switzerland  Cicchetteria Da Rosa
# 8             Ohmstrasse 11, 8050 Zürich, Switzerland              Concerto
# 9             Limmatquai 82, 8001 Zürich, Switzerland               Bianchi
# 10    Stampfenbachstrasse 8, 8001 Zürich, Switzerland            Commihalle
# 11              In Gassen 6, 8001 Zürich, Switzerland              Bindella
# 12            Schmidgasse 3, 8001 Zürich, Switzerland               Toscano
# 13      Niederdorfstrasse 7, 8001 Zürich, Switzerland               Pulcino
# 14     Niederdorfstrasse 15, 8001 Zürich, Switzerland             Vallocaia
# 15                      215, 8005 Zürich, Switzerland                Cinque
# 16          Weberstrasse 14, 8004 Zürich, Switzerland             Il Giglio
# 17         Mainaustrasse 23, 8008 Zürich, Switzerland                Amalfi
# 18         Luisenstrasse 40, 8005 Zürich, Switzerland                Cucina
# 19    Waffenplatzstrasse 15, 8002 Zürich, Switzerland             Don Leone
#
#     Rating
# 0      4.6
# 1      4.4
# 2      4.4
# 3      4.5
# 4      4.6
# 5      4.5
# 6      4.3
# 7      4.5
# 8      4.2
# 9      4.4
# 10     4.1
# 11     4.4
# 12     4.6
# 13     3.9
# 14     4.0
# 15     4.2
# 16     4.4
# 17     4.2
# 18     4.3
# 19     4.2

# %% [markdown]
# Aber, das sind nur 20. Wir wollen mehr. Dafür müssen wir mit diesem Nexttoken arbeiten.

# %%
import time

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+Jouxtens-Mézery&"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
key = "key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&"
pagetoken = ''

result = range(4)
while len(result) > 3: 

    api_query = url+query+fields+key+pagetoken
    print(api_query)
    time.sleep(2)
    r = requests.get(api_query)
    result = r.json()
    if len(result) > 3:
        pagetoken = 'pagetoken='+result['next_page_token']  
        for elem in result['results']:
            address = elem['formatted_address']
            name = elem['name']
            rating = elem['rating']
    
            mini_dict = {'Addresse': address, 
                 'Name': name,
                 'Rating': rating}
    
            new_list.append(mini_dict)
    else:
        break
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Jouxtens-Mézery&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Jouxtens-Mézery&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&pagetoken=CqQCHwEAAIvxCVBJMRuQUpTgqev0r5Fc_SXQbgFBjA6y2EigtI49N8MCoqW2bPwfnFAtHwwxkw3bwq4wL2BBx1bsCKfMyOBl3wK3Z69hBoNjwZU0Vz252XYRyrPOQGQ6cJ8GQsH_NOoH0Oc7F70lXIQ41JT-70lPW4jmu0b-nZyr28cGPqphuPnLd9DXijG09Am7nKHU1d_AZ6_EmumCnkSHXiucIWDHwkqIxTeQ6zr1Mau_NO5ZCuOz8mcZqGreLGOsDXvI5W8_CjydJIk7AYiChrYkpUmLQMc7SCcfX6AdxLOtd9mu6TRMSUZzJELnTAy--taIv_QUvCL0rJH6z4TRZoOjRdaqnb-eVwf_J104OsUuKpkwNwh5IgSuMNR0FudirEeSrRIQea7mFYnzp65gmKXhMsEgehoUsBoHZRuuWZI58QHt5vlwMIdAMGU
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Jouxtens-Mézery&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&pagetoken=CsQDvwEAALcthjX8wcBLQ8s6VuvlsqkPE0on1oEKtwoa5SshiWS2mN_vQHfwmW-KiNkfPeIjwl313pkajQOH7kTXFlW0lA5kQ0Y0nKmdQ3jBXPR_V34jKFwJ1GD-1YMw3oD5ZG-VMqZabBC1dLLfuwE1eixbYNXCQKgMbnTqmLrF3K3XMi1NOi12NIe7ROBRRwVo2LXMXexYuOm9J3js2Vo4hqLWEjp8j8KkGht4xSmAw3Y2E9cVVkDIoyeUBcA_Wxwc74DW9OGhNUgeQ2o4H2FtzIXLEfQI_uEzMAPJXnRpYuIV-A1xJkyEkKAZqRGUUIvU94pr4Atp_sIJW9iXLao6Qvjkn8v5Avvp_afW5wYx6euYmWIeyXM9Q1nHvo49JcRCv6p-_Es4RdfmKMWB1rDGQxrunfMe34gCQf3ROpVywj-MxltG9vb5NFzHA-ZDWXHDebe82SIWlnEzw31-yF5wTpECuUm4FDTZCx95_-L-WpNiqwi6rbm4n1vwJ1avP_DTC2Os7KBwJKEPTtYK2_rkondyGD48ySpIcFzvA8fGI5P7TqpgGG4-Va3sgJwBscITjYIEW9aWHAuv2G95JvXKREOqQ2gSEMcXYjDj6MVK5iGZQoS1UFMaFBOhVChypIYXF0GsoW5yFAPmiySG

# %%
pd.DataFrame(new_list)
# Out:
#                                              Addresse  \
# 0        Avenue du Temple 2, 1020 Renens, Switzerland
# 1     Avenue de la Poste 22, 1020 Renens, Switzerland
# 2   Avenue d'Echallens 72, 1004 Lausanne, Switzerland
# 3        Rue de Lausanne 23, 1020 Renens, Switzerland
# 4   Chemin des Clochetons 41, 1004 Lausanne, Switz...
# 5   Chemin de Couvaloup 13, 1005 Lausanne, Switzer...
# 6    Rue de l'Industrie 4, 1030 Bussigny, Switzerland
# 7    Chemin des Cèdres 2B, 1004 Lausanne, Switzerland
# 8      Place de la Gare 4, 1003 Lausanne, Switzerland
# 9      Route de Reculan 1, 1024 Ecublens, Switzerland
# 10     Rue Saint-Pierre 3, 1003 Lausanne, Switzerland
# 11         Rue Marterey 9, 1005 Lausanne, Switzerland
# 12         Rue du Simplon 4, 1020 Renens, Switzerland
# 13      Voie du Chariot 6, 1003 Lausanne, Switzerland
# 14      Rue de la Barre 5, 1003 Lausanne, Switzerland
# 15        Rue Marterey 25, 1005 Lausanne, Switzerland
# 16  Sentier de la Fleur-de-Lys 4, 1008 Prilly, Swi...
# 17   Avenue du Théâtre 12, 1005 Lausanne, Switzerland
# 18   Avenue de la Gare 20, 1003 Lausanne, Switzerland
# 19  Route du Bois-Genoud 36, 1023 Crissier, Switze...
# 20  Avenue Emile-Henri-Jaques-Dalcroze 9, 1007 Lau...
# 21      Via Valentino, 12, 1004 Lausanne, Switzerland
# 22    Avenue Mon-Repos 14, 1005 Lausanne, Switzerland
# 23   Avenue de la Gare 52, 1003 Lausanne, Switzerland
# 24        Rue de Bourg 28, 1003 Lausanne, Switzerland
# 25    Route de Neuchâtel 73, 1008 Prilly, Switzerland
# 26  Chemin des Falaises 1, 1005 Lausanne, Switzerland
# 27   Avenue de Chailly 13, 1012 Lausanne, Switzerland
# 28  Avenue des Baumettes 11, 1020 Renens, Switzerland
# 29  Avenue de la Sallaz 31, 1005 Lausanne, Switzer...
# 30       Rue du Bugnon 46, 1005 Lausanne, Switzerland
# 31  Route du Châtelard 56, 1018 Lausanne, Switzerland
# 32  Avenue des Baumettes 25, 1020 Renens, Switzerland
# 33  Route de Cossonay 1, 1029 Villars-Sainte-Croix...
# 34  Rlle des Tanneurs 1003, 1003 Lausanne, Switzer...
# 35  Rue de l'Industrie 19, 1023 Crissier, Switzerland
# 36      Rue du Villars 36, 1024 Ecublens, Switzerland
# 37      Rue de Lausanne 49h, 1020 Renens, Switzerland
# 38    Place de la Gare 12, 1003 Lausanne, Switzerland
# 39  Chemin de Bourg-Dessus 1, 1020 Renens, Switzer...
#
#                                       Name  Rating
# 0                 Restaurant La Rose Rouge     4.1
# 1                    La Scarpetta Pizzeria     3.9
# 2                       Ristorante St Paul     4.7
# 3                    Trattoria du Commerce     4.0
# 4                                 cucina41     4.4
# 5                                    Ulivo     4.3
# 6                              Les Arcades     3.8
# 7                           Milano's Pizza     4.4
# 8                                  Vapiano     4.0
# 9                       Pizzeria Al Grotto     2.8
# 10                                  Luigia     4.2
# 11           Restaurant L'Antica Trattoria     4.3
# 12                      L'Escale Gourmande     4.3
# 13                   Leonardo Bar and Food     3.8
# 14                           Caffe Bellini     3.9
# 15                   Restaurant Bravissimo     4.5
# 16  Restaurant la Vague, Piscine de Prilly     3.7
# 17                   Restaurant du Théâtre     4.3
# 18                Restaurant La Bruschetta     4.2
# 19                Le Castel de Bois Genoud     4.4
# 20                               Watergate     3.5
# 21                     I Giardini d'Italia     3.5
# 22    Restaurant Pizzeria Gigio’s Lausanne     3.9
# 23                              Bella Vita     3.5
# 24                              Chez Mario     4.3
# 25              Auberge de la Fleur de Lys     4.4
# 26        Restaurant-pizzeria Les Falaises     3.5
# 27                              Au charbon     4.1
# 28                             Dae-gest Sa     3.4
# 29  L'Amica - M. et F. Alves Da Cunha Sàrl     3.6
# 30                             Chez Sophie     0.0
# 31                         Pizzeria Napoli     3.8
# 32           Restaurant Le Tournoi, Santin     3.9
# 33              Restaurant Le Contemporain     4.0
# 34                                Perbacco     4.6
# 35                            Nico's Pizza     4.3
# 36                         Le Café Vaudois     4.2
# 37                    Brasserie La Croisée     4.4
# 38                               Le Ticino     4.1
# 39                 Ristorante Magna Grecia     4.8

# %% [markdown]
# Das ist leider nicht zufriedenstellend, denn offenbar begrenzt sich Google selber. Wir müssen die nexttoken Suche mit einer Suche nach Städten erweitern. Suchen wir "schweizer städte .csv" bei Google.

# %% [markdown]
# ## Ergänzung Schweizer Städte

# %%
from bs4 import BeautifulSoup

# %%
r = requests.get("https://de.wikipedia.org/wiki/Liste_der_St%C3%A4dte_in_der_Schweiz#St%C3%A4dte_mit_mindestens_10'000_Einwohnern")

# %%
soup = BeautifulSoup(r.text, 'lxml')
cities = []
for elem in soup.find('table').find_all('td', {'align':'left'})[0::2]:
    cities.append(elem.text.replace(" 1", "").replace(' / 3', ''))

# %%
len(cities)
# Out:
# 148

# %% [markdown]
# ## Jetzt ergänzen wir diese Städte

# %%
new_list = []

url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
query = "query=italienische+restaurants+in+"
fields = "fields=formatted_address,name,rating,opening_hours,pagetoken&"
key = "key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&"
pagetoken = ''

for city in cities[:10]:
    result = range(4)
    while len(result) > 3: 

        api_query = url+query+city+"&"+fields+key+pagetoken
        print(api_query)
        time.sleep(1.2)
        r = requests.get(api_query)
        result = r.json()
        if len(result) > 3:
            pagetoken = 'pagetoken='+result['next_page_token']  
            for elem in result['results']:
                address = elem['formatted_address']
                name = elem['name']
                rating = elem['rating']
    
                mini_dict = {'Addresse': address, 
                 'Name': name,
                 'Rating': rating,
                 'Stadt':city}
    
                new_list.append(mini_dict)
        else:
            pagetoken = ''
            break
# Out:
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Zürich&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&pagetoken=CqQCFgEAAKhVqrI620-8T3Owgg40Uf2rfhSzGIwEmDVOCm0QkY3ndQvqpmzKFSK-e1PcqCZa2W5-1tqKF7qcVv009OCq6IuH_UxFQXRh9XIUNsiqwqwViYVL3i19DCDmBIU-p0t1vu1ctQ-0Ao81-jIzR76hF54_pPWYojdcXjGrkg37kkbyIxUik3eRrHXRO4URz57iLb4iOey5KLD2CduHGlm5Qfucd9EqNuNYAzkCKpBXUgd77YfWF4-ewhDEcEBE8TzENT0E7XojSypOME6L12NOp5mFrmqGPdO0_E2ZHik_ar7hmHfbkLPih6zE8zb_8UGc7KuQEvZ9W1Z0K5GeTpNv4bmPDbmfZ9yhVLzrpnEXBwMnOm9_zDn-6vFNpU79e3GiThIQjFoAiZtautrv_neixcEhnxoUZDavBXxK7LLqRjzwpcUsLnhYzBY
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Genf&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Genf&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&pagetoken=CqQ
fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&pagetoken=CqQCGQEAAHheviDssVSka7ESp1U89TloxHlk08njVqH6NyDSb9KFrG7WVIZScg1pPY0H8lfvY6NYSs2P0OtQvC1F92Li001s2O9PGcXa-W0ff9P5WtyKm64iJIpfZK_rKGu9Zct2kcn6f9GYf2S2-Kd4tQKiz4wrdIt1heokZNDqUqAyKuyFiK8ADxKWmkkCVLqtCcBSdRl3VZEK6CzVMTsZDOQUwF9QavsiRIvx5zvq2EXVAHM52es_PgwKb9_it75aTxodgkmt26EKSMyOnYOQX8S5fW8-4DBIsmbxwn0c_zR_g29Kh8Gzu3oPQCuIUukEGj_fD0NMMz7T9LEe6qgNp3qKzSreMP_rOLQ0bFoaxU4o2RS-CFSBSCp_e0l16XH6ljCloBIQK5T_KHfJg1o2s0FQrNrz0RoUs0COq6YFJVv7HzceXPesY8zW5-8
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Lugano&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&pagetoken=CqQCFQEAANNlA66t1sbLJcO-bjjrH6yBJkIOQ86i_IiXPnnjZvRB9gQr_FRDeXKdoGhqKsPXXVNd0WKyuAjfpm7uRzjAfaRsl5Qtt89TlbCuPvTbAH7ySyDPXWmDRGYKmtqB_xQjAD_-phFCJ_v7jtYZexdB0VrskTmltSg2qjak42BaxWNyl8cRocduIYOSpa-Anox6aJ06eNclNzFt6Qni6cQj5vcLhzACeXbi41DfCiDf1TUaEyBdT_n-x6zr3nmbxnHnE2EPHQWW9oFEv_MmpHuh-jobBzUoDzt5hzF5SMsUUpSX_8tLp31Pmz3y5VJcK5FuCqRpZe9OxmIoggvI85X2LFUd2erARhd94b0aN35U9RSpzS8-BKZTdKTCdEHY8K_mLxIQ6IprpRPX2bMVwy53HZ9P9hoU6JF2T8FT9LCecSqmpxuZv5aqgQ4
# https://maps.googleapis.com/maps/api/place/textsearch/json?query=italienische+restaurants+in+Biel/Bienne&fields=formatted_address,name,rating,opening_hours,pagetoken&key=AIzaSyDSBsxGHn_vfCl3ECzps4Pyee-vG3Tcdww&

# %%
df = pd.DataFrame(new_list)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 4 columns):
# Addresse    240 non-null object
# Name        240 non-null object
# Rating      240 non-null float64
# Stadt       240 non-null object
# dtypes: float64(1), object(3)
# memory usage: 7.6+ KB

# %%
df = df.drop_duplicates()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 4 columns):
# Addresse    240 non-null object
# Name        240 non-null object
# Rating      240 non-null float64
# Stadt       240 non-null object
# dtypes: float64(1), object(3)
# memory usage: 9.4+ KB

# %%
df.sort_values(by='Rating')
# Out:
#                                               Addresse  \
# 103          Länggasstrasse 19, 3012 Bern, Switzerland
# 235    Riva Antonio Caccia 7, 6900 Lugano, Switzerland
# 152  Avenue des Deux-Ponts 13, 1009 Pully, Switzerland
# 176       Industriestr 8, 8404 Winterthur, Switzerland
# 195          Metzgerrainle 9, 6004 Luzern, Switzerland
# 212   Zürcherstrasse 118, 9000 St. Gallen, Switzerland
# 139      Via Valentino, 12, 1004 Lausanne, Switzerland
# 148  Chemin des Falaises 1, 1005 Lausanne, Switzerland
# 150  Avenue Emile-Henri-Jaques-Dalcroze 9, 1007 Lau...
# 112                 Bärenpl. 7, 3011 Bern, Switzerland
# 104           Landoltstrasse 1, 3007 Bern, Switzerland
# 137   Avenue de la Gare 52, 1003 Lausanne, Switzerland
# 194           Rathausquai 11, 6004 Luzern, Switzerland
# 156  Avenue de la Sallaz 31, 1005 Lausanne, Switzer...
# 193         Bahnhofstrasse 7, 6003 Luzern, Switzerland
# 77        Hardstrasse 13, 4127 Birsfelden, Switzerland
# 95                  Bärenpl. 9, 3011 Bern, Switzerland
# 63              Riehenring 79, 4058 Basel, Switzerland
# 228     Via Clemente Maraini, 6900 Lugano, Switzerland
# 60          Steinenvorstadt 1, 4051 Basel, Switzerland
# 37            Rue Sautter 11, 1205 Genève, Switzerland
# 213       Poststrasse 27, 9000 St. Gallen, Switzerland
# 75      Holzmattenweg 13, 79576 Weil am Rhein, Germany
# 64             Clarastrasse 1, 4058 Basel, Switzerland
# 136      Voie du Chariot 6, 1003 Lausanne, Switzerland
# 100         Riedbachstrasse 98, 3027 Bern, Switzerland
# 219       Oberstrasse 30, 9000 St. Gallen, Switzerland
# 56          Untere Rebgasse 4, 4058 Basel, Switzerland
# 94               Spitalgasse 2, 3011 Bern, Switzerland
# 22         Rue Chaponnière 9, 1201 Genève, Switzerland
# ..                                                 ...
# 1            Hohlstrasse 449, 8048 Zürich, Switzerland
# 5              Schmidgasse 3, 8001 Zürich, Switzerland
# 167    Steinberggasse 24, 8400 Winterthur, Switzerland
# 115         Seftigenstrasse 32, 3007 Bern, Switzerland
# 164       Wartstrasse 24, 8400 Winterthur, Switzerland
# 151  Rlle des Tanneurs 1003, 1003 Lausanne, Switzer...
# 175      Agnesstrasse 42, 8406 Winterthur, Switzerland
# 178   Scheideggstrasse 6, 8400 Winterthur, Switzerland
# 141      Rue Cité-Devant 6, 1005 Lausanne, Switzerland
# 182             Rütligasse 2, 6003 Luzern, Switzerland
# 55              Sattelgasse 3, 4051 Basel, Switzerland
# 113             Belpstrasse 34, 3007 Bern, Switzerland
# 0    Am Münsterhof, Waaggasse 7, 8001 Zürich, Switz...
# 93          Freiburgstrasse 68, 3008 Bern, Switzerland
# 204  Geltenwilenstrasse 15, 9000 St. Gallen, Switze...
# 70          Horburgstrasse 74, 4057 Basel, Switzerland
# 96              Belpstrasse 65, 3003 Bern, Switzerland
# 68           Fabrikstrasse 12, 4056 Basel, Switzerland
# 46              Rheingasse 47, 4058 Basel, Switzerland
# 233          Via Cantonale 1, 6900 Lugano, Switzerland
# 147    Avenue de Tivoli 60, 1007 Lausanne, Switzerland
# 208     Gallusstrasse 39, 9000 St. Gallen, Switzerland
# 69           Güterstrasse 138, 4053 Basel, Switzerland
# 198       Industriestrasse 7, 6005 Luzern, Switzerland
# 122  Avenue d'Echallens 72, 1004 Lausanne, Switzerland
# 18          Freiestrasse 213, 8032 Zürich, Switzerland
# 234     Via Luigi Canonica 5, 6900 Lugano, Switzerland
# 16           Rudolfstrasse 6, 8008 Zürich, Switzerland
# 192         Burgerstrasse 22, 6003 Luzern, Switzerland
# 177   Tösstalstrasse 244, 8405 Winterthur, Switzerland
#
#                                        Name  Rating       Stadt
# 103         Pizza Subito da Giovanni Iacono     0.0        Bern
# 235                   Ristorante La Veranda     0.0      Lugano
# 152                      restaurant italien     0.0    Lausanne
# 176                    Angolo Pizza & Pasta     3.0  Winterthur
# 195                             La Terrazza     3.1      Luzern
# 212      Restaurant Barbarossa Pizza Kurier     3.3  St. Gallen
# 139                     I Giardini d'Italia     3.5    Lausanne
# 148        Restaurant-pizzeria Les Falaises     3.5    Lausanne
# 150                               Watergate     3.5    Lausanne
# 112                     Ristorante La Gioia     3.5        Bern
# 104                  Pizzaiolo Pizza-Kurier     3.5        Bern
# 137                              Bella Vita     3.5    Lausanne
# 194                              Da Ernesto     3.5      Luzern
# 156  L'Amica - M. et F. Alves Da Cunha Sàrl     3.6    Lausanne
# 193                                 Rossini     3.6      Luzern
# 77             Pizzakurier Restaurant Luxor     3.6       Basel
# 95                    Plattform Restaurants     3.6        Bern
# 63           Roma Messe Pizzeria Restaurant     3.6       Basel
# 228                  AnaCapri Ristorante SA     3.7      Lugano
# 60                      Ristorante La Sosta     3.7       Basel
# 37                    Restaurant Le Vivendo     3.7        Genf
# 213          Restaurant Walhalla St. Gallen     3.7  St. Gallen
# 75    Pizzeria Mooshüsli, Café - Restaurant     3.7       Basel
# 64                    Restaurant Holzschopf     3.7       Basel
# 136                   Leonardo Bar and Food     3.8    Lausanne
# 100                        SPIGA Ristorante     3.8        Bern
# 219                      Pizzeria Da Angelo     3.8  St. Gallen
# 56                          Detto Pronto AG     3.8       Basel
# 94                      Ristorante Da Vinci     3.8        Bern
# 22                         Restaurant MILAN     3.8        Genf
# ..                                      ...     ...         ...
# 1                                 Da Angela     4.6      Zürich
# 5                                   Toscano     4.6      Zürich
# 167                                 Insieme     4.6  Winterthur
# 115                    Abyssinia Restaurant     4.6        Bern
# 164                    Ristorante Sottovoce     4.6  Winterthur
# 151                                Perbacco     4.6    Lausanne
# 175                       Pizzeria Cardinal     4.6  Winterthur
# 178        Gianni's Pizza-Kurier Winterthur     4.6  Winterthur
# 141                              Il ghiotto     4.6    Lausanne
# 182                              il Cortile     4.6      Luzern
# 55                          Trattoria aroma     4.6       Basel
# 113                       Ristorante Ottimo     4.6        Bern
# 0                         Ristorante Orsini     4.6      Zürich
# 93           Ristorante Pizzeria Settebello     4.6        Bern
# 204                         Forchetta D'Oro     4.6  St. Gallen
# 70                Ristorante Mamma Brunella     4.6       Basel
# 96            Pizzeria Eigerplatz "Da Nino"     4.7        Bern
# 68                           Osteria Dodici     4.7       Basel
# 46                            Gabri's Pasta     4.7       Basel
# 233                   La Trattoria a Lugano     4.7      Lugano
# 147                               Zafferano     4.7    Lausanne
# 208                    Ristorante Facincani     4.7  St. Gallen
# 69                                     VITO     4.7       Basel
# 198                           Grottino 1313     4.7      Luzern
# 122                      Ristorante St Paul     4.7    Lausanne
# 18                      Antiquario da Marco     4.7      Zürich
# 234                                   Deseo     4.8      Lugano
# 16                                  Gandria     4.8      Zürich
# 192                            Punto Giusto     4.8      Luzern
# 177                          Pizzeria Sonne     5.0  Winterthur
#
# [240 rows x 4 columns]

# %%
df[df['Rating']!=0.0].groupby('Stadt')['Rating'].mean().sort_values(ascending=False)
# Out:
# Stadt
# Zürich        4.380000
# Lugano        4.294737
# Winterthur    4.290000
# St. Gallen    4.220000
# Genf          4.215000
# Luzern        4.210000
# Basel         4.185000
# Bern          4.169231
# Lausanne      4.141026
# Name: Rating, dtype: float64
