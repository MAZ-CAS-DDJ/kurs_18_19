# %% [markdown]
# ## Dictionaries in Python
#
# Dictionaries sind unglaublich praktisch, damit kannst du z. B. folgendes machen:
#
# - Du kannst Wertezuordnungen speichern (z.B. Telefonbuch: Ein Nachname hat eine Telefonnummer).
# - Du kannst nachträglich Elemente verändern / entfernen / hinzufügen.
# - Dictionaries brauchst du wirklich immer wieder...
#
# Machen wir mal ein Beispiel...

# %%
d = {"Berlin": "BER", "Helsinki": "HEL", "Saigon": "SGN"}

# %%
print(d)
# Out:
# {'Berlin': 'BER', 'Helsinki': 'HEL', 'Saigon': 'SGN'}

# %% [markdown]
# Zugriff auf ein einzelnes Element:

# %%
print(d["Helsinki"])
# Out:
# HEL

# %% [markdown]
# Hiermit überschreibst du ein einzelnes Element:

# %%
d["Budapest"] = "BUD"

# %%
print(d)
# Out:
# {'Berlin': 'BER', 'Helsinki': 'HEL', 'Saigon': 'SGN', 'Budapest': 'BUD'}

# %% [markdown]
# ## Element entfernen

# %%
del d["Budapest"]

# %%
print(d)
# Out:
# {'Berlin': 'BER', 'Helsinki': 'HEL', 'Saigon': 'SGN'}

# %% [markdown]
# ## Abfrage: Ist ein Element im Dictionary?

# %%
if "Budapest" in d:
    print("Budapest ist im Dictionary enthalten")
if "Saigon" in d:
    print("Saigon ist im Dicionary enthalten")
# Out:
# Saigon ist im Dicionary enthalten

# %% [markdown]
# ## Auf Elemente zugreifen...

# %%
print(d["Saigon"])
print(d.get("Saigon"))
# Out:
# SGN
# SGN

# %% [markdown]
# Warum sollte man get nutzen? Man kann doch auch einfach so drauf zugraifen? Die Lösung ist einfach aber sehr praktisch. Fehlertoleranz.

# %%
print(d["Budapest"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-9a8194eb0769> in <module>()
# ----> 1 print(d["Budapest"])
#
# KeyError: 'Budapest'

# %%
print(d.get("Budapest"))
# Out:
# None

# %% [markdown]
# ## Dictionaries und Schleifen
#
# Du hast bei Dictionaries 2 Möglichkeiten, diese mit einer for - Schleife durchzugehen.
#
# Entweder direkt, dann gehst du die Schlüssel durch:

# %%
d = {"München": "MUC", "Budapest": "BUD", "Helsinki": "HEL"}

for key in d: 
    value = d[key]
    print(key)
    print(value)
# Out:
# München
# MUC
# Budapest
# BUD
# Helsinki
# HEL

# %% [markdown]
# Oder über die .items() - Methode, damit kannst du Schlüssel + Wert direkt durchgehen:

# %%
for key, value in d.items():
    print(key + ": " + value)
# Out:
# München: MUC
# Budapest: BUD
# Helsinki: HEL

# %% [markdown]
# ## Übung 1
# Wie oft kommt jedes wort in der liste vor?

# %%
liste = ["Hallo", "Hallo", "Welt", "Hallo", "Mars"]

d = {}
for element in liste:
    if element in d:
        d[element] = d[element] + 1
    else:
        d[element] = 1
    
print(d)

# %% [markdown]
# ## Übung 2 Hardcore

# %% [markdown]
# Wir trauen uns zum ersten mal an einen "echten" datensatz. http://p3.snf.ch/Pages/DataAndDocumentation.aspx

# %%
import requests
import csv
data = requests.get("http://p3.snf.ch/P3Export/P3_PersonExport.csv").text.splitlines()
personen = csv.DictReader(data,delimiter=';')

# %%
next(personen)
# Out:
# OrderedDict([('Last Name', 'Auderset'),
#              ('First Name', 'Dominique'),
#              ('Gender', 'female'),
#              ('Institute Name',
#               "Lab. d'Ecologie et de Biologie Aquatique Institut des Sciences de l'Environnement Université de Genève"),
#              ('Institute Place', 'Carouge'),
#              ('Person ID SNSF', '8406'),
#              ('ORCID', ''),
#              ('Projects as responsible Applicant', ''),
#              ('Projects as Applicant', '8521'),
#              ('Projects as Partner', ''),
#              ('Projects as Practice Partner', ''),
#              ('Projects as Employee', '8521'),
#              ('Projects as Contact Person', '')])

# %% [markdown]
# Welche Institute hatten die meisten beiteiligten personen?

# %%
institutes = {}
for row in personen:
    if institutes.get(row["Institute Place"]) == None:
        institutes[row["Institute Place"]] = 1 
    else:
        institutes[row["Institute Place"]] += 1
institutes
# Out:
# {'Bern': 3758,
#  '': 51230,
#  'Genève 4': 2330,
#  'Lausanne': 5114,
#  'Zürich': 9363,
#  'Belvaux': 4,
#  'St. Gallen': 726,
#  'Luzern': 353,
#  'Luzern 16': 15,
#  'Grenoble': 12,
#  'Lausanne 25': 10,
#  'Neuchâtel': 632,
#  'Bern 60 UPD': 64,
#  'Linz': 11,
#  'Wuppertal': 7,
#  'Helsinki': 20,
#  'Graz': 25,
#  'Lugano': 366,
#  'Genève 21': 127,
#  'Karnataka': 2,
#  'Marseille': 13,
#  'Basel': 3650,
#  'München': 106,
#  'Fribourg': 1325,
#  'Manchester': 21,
#  'Orsay': 8,
#  'Genève': 845,
#  'Cambridge': 456,
#  'Montpellier': 21,
#  'Tampere': 4,
#  'Garching b. München': 7,
#  'Vancouver': 76,
#  'Milano': 51,
#  'Tuzla': 8,
#  'Moscow': 121,
#  'Burnaby': 10,
#  'Manno': 81,
#  'Stavropol': 1,
#  'Rennes': 6,
#  'Genève 14': 573,
#  'London': 279,
#  'ADO EKITI': 1,
#  'Neuchâtel 9': 128,
#  'Okayama': 1,
#  'Chêne-Bourg': 126,
#  'Havana': 3,
#  'Epalinges': 296,
#  'New York': 233,
#  'Kokshetau': 1,
#  'Düsseldorf': 24,
#  'Berlin': 176,
#  'Yerevan': 28,
#  'Baltimore': 27,
#  'Montréal': 105,
#  'Luxembourg': 14,
#  'Lisbon': 5,
#  'Dundee': 6,
#  'Hildesheim': 1,
#  'Tashkent': 24,
#  'Cambridge, MA': 9,
#  'Baku': 6,
#  'Kiel': 17,
#  'Delémont': 24,
#  'Paris': 153,
#  'St-Ursanne': 2,
#  'San Francisco': 54,
#  'Chicago': 48,
#  'Roma': 44,
#  'Neuchâtel 7': 58,
#  'Sydney': 54,
#  'Birmensdorf ZH Kaserne': 25,
#  'Chisinau': 32,
#  'Dübendorf': 436,
#  'Kastanienbaum': 30,
#  'La Jolla': 121,
#  'Clayton': 10,
#  'Tägerwilen': 1,
#  'Lausanne Adm cant VD': 20,
#  'Tel Aviv': 9,
#  'Marburg': 24,
#  'Avignon': 2,
#  'Bern 9': 307,
#  'Lindau': 37,
#  'Bethesda': 21,
#  'Bruxelles': 20,
#  'Schwarzenburg': 1,
#  'Schlieren': 116,
#  'Olten': 93,
#  'Wetzikon ZH': 2,
#  'Ste-Croix': 2,
#  'Frankfurt am Main': 24,
#  'Valens': 5,
#  'Schwerzenbach': 62,
#  'Bern 26': 1,
#  'Hamburg': 65,
#  'Burgdorf': 14,
#  'Genève 6': 22,
#  'Talence': 2,
#  'Stuttgart': 44,
#  'Castelldefels': 2,
#  'Bordeaux Cedex': 3,
#  'Barmelweid': 6,
#  'Wako': 4,
#  'Seattle': 52,
#  'Regensburg': 10,
#  'Zofingen': 2,
#  'Bern 22': 13,
#  'Villigen PSI': 457,
#  'Aachen': 28,
#  'Guelph': 7,
#  'Moudon': 5,
#  'Birmensdorf ZH': 165,
#  'Winterthur': 236,
#  'Stanford': 133,
#  'Crawley': 6,
#  'Nedlands': 1,
#  'Arbon': 1,
#  'Davos Platz': 52,
#  'Givisiez': 12,
#  'Genève 8': 19,
#  'Prilly': 102,
#  'Leuven': 23,
#  'Göttingen': 36,
#  'Halle': 5,
#  'Wien': 162,
#  'Kyoto': 14,
#  'Jinja': 4,
#  'St. Peterburg': 5,
#  'New Haven': 45,
#  'Paris Cedex 05': 31,
#  'Atlanta': 26,
#  'Zug': 34,
#  'Debrecen': 4,
#  'Maputo': 8,
#  'Wädenswil': 91,
#  'Neuchâtel 2': 67,
#  'Parkville': 23,
#  'Nyon': 20,
#  'Boston': 163,
#  'Zagreb': 40,
#  'Dubna': 5,
#  'Ann Arbor': 35,
#  'Durham': 35,
#  'Tbilisi': 76,
#  'Sarajevo': 17,
#  'Bonn': 42,
#  'MB Eindhoven': 10,
#  'Norrköping': 1,
#  'Genève 1': 59,
#  'Orsay cedex': 5,
#  'Berkeley': 156,
#  'Leganes (Madrid)': 2,
#  'Tiblisi': 2,
#  'Budapest': 34,
#  'Flensburg': 1,
#  'Princeton': 45,
#  'Heidelberg': 97,
#  'Ancona': 1,
#  'Sion': 121,
#  'Genève 9': 29,
#  'Locarno': 55,
#  'Yverdon': 34,
#  'Bochum': 19,
#  'Strasbourg Cedex': 13,
#  'Orlando': 3,
#  'Genève 17': 1,
#  'Liestal': 47,
#  'Kreuzlingen': 21,
#  'Göteborg': 15,
#  'Nyon 1': 24,
#  'Stein AG': 1,
#  'Los Angeles': 79,
#  'Köln': 38,
#  'Erlangen': 16,
#  'Bucharest': 54,
#  'Solothurn': 34,
#  'Bern 7': 17,
#  'Dresden': 43,
#  'Penryn, Cornwall': 3,
#  'Pittsburgh': 22,
#  'Katlenburg-Lindau': 3,
#  'Venezia': 9,
#  'Cluj-Napoca': 23,
#  'La Chaux-de-Fonds': 28,
#  'Pasadena': 67,
#  'Crawley ': 2,
#  'Innsbruck': 35,
#  'Kharagpur, West Bengalie': 1,
#  'Conches': 10,
#  'Zeuthen': 1,
#  'Gödöllo': 1,
#  'Biel/Bienne': 50,
#  'Cully': 1,
#  'Madrid': 27,
#  'Oxford': 154,
#  'Uppsala': 22,
#  'Zollikofen': 46,
#  'Bratislava': 12,
#  'Rapperswil SG': 27,
#  'Ekaterinburg': 8,
#  'Carouge GE': 67,
#  'Torino': 18,
#  'Versoix': 42,
#  'Padova': 11,
#  'Martigny': 48,
#  'Zaragoza': 3,
#  'Lausanne 19': 3,
#  'Luterbach': 2,
#  'Lenzburg': 1,
#  'Bellinzona': 143,
#  'Rio de Janeiro': 12,
#  'Cardiff': 5,
#  'Beirut': 3,
#  'Chernogolovka': 3,
#  'Dallas': 9,
#  'Hong Kong': 6,
#  'Palaiseau Cedex': 5,
#  'Minsk': 17,
#  'Houston': 13,
#  'Amsterdam': 44,
#  'Esch-sur-Alzette (Belval)': 1,
#  'Trieste': 16,
#  'Orsay Cedex': 3,
#  'Toronto': 55,
#  'Boudry': 1,
#  'Neuchâtel 1': 3,
#  'Akron': 1,
#  'Barcelona': 47,
#  'Coventry': 26,
#  'Bath': 5,
#  'Tübingen': 53,
#  'Davos Dorf': 76,
#  'Stockholm': 49,
#  'State College': 1,
#  'Sauverny': 39,
#  'West Lafayette': 6,
#  'Paris 05': 1,
#  'Parma': 4,
#  'Schriesheim': 1,
#  'Munich': 2,
#  'Genève 22': 4,
#  'Hartford': 1,
#  'Iowa City': 4,
#  'Toulouse Cedex 4': 2,
#  'Bruderholz': 23,
#  'Pretoria': 13,
#  'Chennai': 7,
#  'Ljubljana': 19,
#  'Moscow, GSP-4': 1,
#  'Honolulu': 9,
#  'Muizenberg': 1,
#  'Vevey': 14,
#  'Giessen': 16,
#  'Granges-Paccot': 11,
#  'Rotterdam': 7,
#  'Sofia': 80,
#  'Rovinj': 1,
#  'Bristol': 32,
#  'Bendern': 6,
#  'Utrecht': 18,
#  'Solna': 6,
#  'Keele': 1,
#  'Genève 28': 4,
#  'Les Acacias': 7,
#  'Redhill': 1,
#  'San Domenico di Fiesole': 12,
#  'Belgrade': 65,
#  'Aarau': 113,
#  'Suhr': 2,
#  'Sempach Stadt': 25,
#  'Windisch': 60,
#  'Freiburg': 54,
#  'Boulder': 30,
#  'Portland': 4,
#  'Aberystwyth': 1,
#  'Santa Barbara': 35,
#  'Nottwil': 29,
#  'Private Bag': 1,
#  'Dortmund': 18,
#  'Copenhagen': 26,
#  'Nairobi': 16,
#  'Brussels': 6,
#  'Messen': 2,
#  'Kilchberg ZH': 12,
#  'Arlesheim': 2,
#  'Maastricht': 4,
#  'PISA': 1,
#  'Ettenhausen TG': 18,
#  'Lyon Cedex 07': 16,
#  'Neuchâtel DT': 5,
#  'Philadelphia': 51,
#  'Mainz': 36,
#  'Rio De Janeiro': 11,
#  'Çankaya/Ankara': 1,
#  'Hinterkappelen': 24,
#  'Ougadougou': 1,
#  'Ankara': 4,
#  'Cadenazzo': 4,
#  'Columbus': 6,
#  'Garching bei München': 5,
#  'Quebec': 3,
#  'Hillerod': 2,
#  'Hannover': 27,
#  'St. Louis': 12,
#  'Loeben': 1,
#  'Riehen': 4,
#  'Phoenix, Arizona': 1,
#  'Münster': 39,
#  'Beijing': 32,
#  'Binningen': 12,
#  'Porrentruy': 10,
#  'Birmingham': 16,
#  'Nottingham': 16,
#  'Kühlungsborn': 4,
#  'Plön': 4,
#  'Leipzig': 39,
#  'Freiburg i.Br.': 8,
#  'Lamone': 1,
#  'Rüschlikon': 63,
#  'Posieux': 6,
#  'Wilrijk': 6,
#  'Forch': 1,
#  'Greifswald-Insel Riems': 1,
#  'Baden': 53,
#  'Frankfurt': 11,
#  'Bevaix': 1,
#  'Thun': 24,
#  'Sainte-Foy': 3,
#  'Belgrad': 4,
#  'Brunswick': 1,
#  'Poznan': 5,
#  'York': 7,
#  'Paris Cédex 05': 12,
#  'Cambridge MA': 6,
#  'La Marsa': 1,
#  'Marcoussis': 3,
#  'Bogota': 4,
#  'Norwich': 9,
#  'GL Amsterdam': 3,
#  'Oswego': 1,
#  'Cleveland': 11,
#  'Mont St-Aignan Cedex': 1,
#  'Pisa': 10,
#  'Krasnoyarsk': 5,
#  'Auckland': 11,
#  'Muttenz': 63,
#  'Freising': 8,
#  'Konstanz': 53,
#  'Carouge': 105,
#  'Mittelhäusern': 18,
#  'Zsambek': 1,
#  'Tunis': 5,
#  'Davis': 17,
#  'Sembrancher': 3,
#  'Basel Hoffmann-La Roche AG': 11,
#  'Kopenhagen': 2,
#  'Mendrisio': 47,
#  'Islamabad': 3,
#  'Mountain View': 2,
#  'Cali-Valle del Cauca': 1,
#  'Gainesville': 8,
#  'Geelong VIC': 1,
#  'Potsdam': 27,
#  'Haifa': 8,
#  'Regina': 1,
#  'Paris Cedex 07': 3,
#  'Villejuif': 2,
#  'Genève 23': 44,
#  'Copenhagen K': 3,
#  'St-Maurice': 10,
#  'Kiev': 44,
#  'Freiburg i. Br.': 10,
#  'Kathmandu, NEPAL': 1,
#  'Dübendorf 2': 2,
#  'Tschugg': 1,
#  'Huddinge': 7,
#  'Dublin 2': 3,
#  'Karlsruhe': 32,
#  'Charlestown': 17,
#  'Müstair': 3,
#  'Potsdam/Golm': 3,
#  'Renens VD 2': 6,
#  'Canberra': 23,
#  'Grenoble Cedex 9': 16,
#  'Romont FR': 10,
#  'Klosterneuburg': 12,
#  'Strasbourg Cedex 2': 3,
#  'Mekelle': 1,
#  'Waltham ,MA': 1,
#  'Las Vegas': 2,
#  'Odessa': 7,
#  'Buchs SG': 3,
#  'Jussy': 14,
#  'Canobbio': 35,
#  'Szczecin': 1,
#  'Thayngen': 1,
#  'Nürnberg': 4,
#  'Grabs': 3,
#  'Bronx': 9,
#  'Altenrhein': 2,
#  'Bergamo': 1,
#  'GA Delft': 1,
#  'Monthey': 5,
#  'Rauenstein': 1,
#  'Horw': 30,
#  'Villars-sur-Ollon': 1,
#  'San Sebastian': 4,
#  'Boston ': 8,
#  'Grenoble Cedex': 3,
#  'Yverdon-les-Bains': 23,
#  'Paris Cedex 04': 1,
#  'Stanford, CA': 6,
#  'Contone': 1,
#  'Haren': 1,
#  'Dijon': 10,
#  'Bordeaux Cédex': 2,
#  'Magdeburg': 8,
#  'Goldau': 9,
#  'Berkshire': 1,
#  "Saint Martin d'Hères Cedex": 2,
#  'Toulouse': 13,
#  'Besançon': 11,
#  'AG Groningen': 2,
#  'Lancaster': 16,
#  'Edinburgh': 40,
#  'Beyoglu-Istanbul': 1,
#  'Buchs ZH': 1,
#  'Lausanne-Chuv': 7,
#  'Renens VD': 1,
#  'Bangalore': 15,
#  'Kolkata': 1,
#  'Coimbatore': 1,
#  'Harbin': 1,
#  'Horgen': 7,
#  "Château-d'Oex": 1,
#  'Turin': 3,
#  'Tromsö': 3,
#  'Biel/Bienne 6': 22,
#  'Frauenfeld': 18,
#  'Orangeburg': 2,
#  'Bussigny-près-Lausanne': 2,
#  'Melbourne': 33,
#  'Darlinghurst, Sydney': 1,
#  'Nieuwegein': 1,
#  'Bamberg': 4,
#  'Minneapolis': 17,
#  'Jena': 27,
#  'Mannheim': 25,
#  'Zollikerberg': 4,
#  'Saskatoon': 2,
#  'Paris Cedex 13': 10,
#  'Pavia': 5,
#  'Modena': 5,
#  'Kosice': 3,
#  'St. Petersburg': 42,
#  'Laufen': 1,
#  'Warsaw': 13,
#  'Mississauga': 2,
#  'Delft': 12,
#  'Neuchâtel DAP': 1,
#  'Rennes Cedex': 6,
#  'Eugene': 3,
#  'Matieland': 8,
#  'Ludwigsburg': 1,
#  'Vaduz': 4,
#  'Balcali - Adana': 2,
#  'Furtwangen': 1,
#  'Ho': 1,
#  'Vercelli': 1,
#  'Kigali': 1,
#  'Invergowrie, Dundee': 1,
#  'Bern-Wabern': 10,
#  'Washington': 21,
#  'Aarhus C': 12,
#  'Lund': 24,
#  'Bergen': 8,
#  'Magglingen/Macolin': 4,
#  'Edmonton': 14,
#  'Homburg/Saar': 1,
#  'Leeds': 7,
#  'Antofagasta': 3,
#  'Amherst': 10,
#  'San Diego': 21,
#  'Galati': 2,
#  'Edmonton, Alberta': 2,
#  'Sherbrooke': 7,
#  'Hertfordshire': 2,
#  'Strasbourg': 22,
#  'Le Mont-sur-Lausanne': 12,
#  'Hobart': 2,
#  'Madera': 1,
#  'Faltigberg': 2,
#  'Fuenlabrada': 1,
#  'Radolfzell': 1,
#  'Knoxville': 1,
#  'Grahamstown': 5,
#  'Maywood': 1,
#  'Regensdorf': 2,
#  'Ithaca': 27,
#  'Aix-en-Provence cedex 1': 4,
#  'Chapel Hill': 12,
#  'Salzburg': 16,
#  'Rorschach': 11,
#  'Leiden': 22,
#  'Visp': 4,
#  'Paderborn': 4,
#  'Freiburg im Breisgau': 13,
#  'St Andrews': 3,
#  'København Ø': 1,
#  'Planegg-Martinsried': 4,
#  'Bayreuth': 18,
#  'Potsdam-Golm': 3,
#  'Chambésy': 20,
#  'Oberrieden': 2,
#  'Ulm': 11,
#  'Krakow': 6,
#  'Frick': 43,
#  'Liebefeld': 13,
#  'Genève 3': 20,
#  'Storrs': 5,
#  'Menlo Park': 13,
#  'Glion': 1,
#  'Ottawa': 13,
#  'Warszawa': 10,
#  'Zollikon': 11,
#  'Bettlach': 4,
#  'Kharkov': 7,
#  'Genève 10': 4,
#  'Simferopol': 2,
#  'Chur': 68,
#  'Braunschweig': 10,
#  'Indianapolis': 4,
#  'Evolène': 2,
#  'Worcester, MA': 2,
#  'Bremen': 26,
#  'Jakarta Selatan': 1,
#  'Sargans': 4,
#  'Düren': 1,
#  'Ecublens VD': 2,
#  'Lusaka': 4,
#  'Sevastopol': 1,
#  'Paris Cedex 15': 6,
#  'Abidjan': 8,
#  'Meyrin': 7,
#  'Cagliari': 1,
#  'Teramo': 1,
#  'Fitzroy': 1,
#  'Firenze': 26,
#  'College Park': 6,
#  'Johannesburg': 16,
#  'Valangin': 1,
#  'Futuroscope Cedex': 1,
#  'Sibari': 1,
#  'Evilard': 1,
#  'Sophia Antipolis': 1,
#  'Washington DC': 3,
#  'Bangkok': 3,
#  'Notthingham': 1,
#  'Villeurbanne': 6,
#  'Oviedo': 2,
#  'Dijon Cedex': 5,
#  'Santiago de Chile': 3,
#  'Timisoara': 18,
#  'Oslo': 28,
#  'Perm': 1,
#  'Darmstadt': 9,
#  'Uster': 10,
#  'San Antonio': 4,
#  'Montpellier Cedex 5': 8,
#  'Redmond': 1,
#  'Lyss': 3,
#  'Klagenfurt': 6,
#  'Allschwil': 20,
#  'Raleigh': 6,
#  'Luzern 7': 12,
#  'Kassel': 8,
#  'La Jolla, California': 1,
#  'Nogent-sur-Marne Cedex': 1,
#  'Umea': 9,
#  'Bremen 1': 1,
#  'Bielefeld': 27,
#  'Jülich': 14,
#  'Groningen': 17,
#  'Verbana Pallanza': 1,
#  'Bundoora VIC': 1,
#  'Mülheim an der Ruhr': 13,
#  'Sophia Antipolis Cedex': 2,
#  'Brüssel': 1,
#  'Malzéville': 1,
#  'Argonne': 3,
#  'Marrakech': 4,
#  'Grenoble cedex 9': 7,
#  'Nanterre Cedex': 8,
#  'Niamey': 4,
#  'Brisbane, QLD': 1,
#  'Lausanne 9': 5,
#  "Saint-Martin d'Heres": 3,
#  'Paris Cedex': 3,
#  'Darlinghurst': 4,
#  'Singapore': 34,
#  'Genève 11': 6,
#  'Bordeaux': 4,
#  'Namur': 2,
#  'Surrey': 5,
#  'Brighton': 11,
#  'Saskatchewan': 2,
#  'Calgary': 21,
#  'Palo Alto': 12,
#  'Paris cedex 13': 1,
#  'Namangan': 1,
#  'Rome': 9,
#  'Glasgow': 22,
#  'Nice Cedex 2': 1,
#  'Ferrara': 1,
#  'Lincoln': 2,
#  'Austin (Texas)': 1,
#  'Porto Alegre': 1,
#  'Badalona': 1,
#  'Bern 8': 9,
#  'University Park': 12,
#  'Hall i.T.': 2,
#  'Umtata': 1,
#  'Cologny': 2,
#  'Sion 4': 14,
#  'Dublin 4, Ireland': 2,
#  'Dublin 4': 3,
#  'Davos Clavadel': 3,
#  'Bern 29': 8,
#  'Jegenstorf': 2,
#  'Chico': 1,
#  'Holderbank AG': 8,
#  'Appenzell': 8,
#  'Riverside': 6,
#  'Vevey 1': 3,
#  'Ludwigshafen': 1,
#  'Fort Collins': 7,
#  'Southampton': 13,
#  'Stellenbosch': 9,
#  'Rehovot': 11,
#  'Issy-Les-Moulineaux': 1,
#  'Cotonou': 3,
#  'Avenches': 3,
#  'Clemson': 2,
#  "Saint Martin d'Hères": 4,
#  'Oslo 5': 1,
#  'Exeter': 7,
#  '22007 Lund': 1,
#  'Aalborg': 3,
#  'Osnabrueck': 1,
#  'Cape Town': 19,
#  'Antwerpen': 7,
#  'Coffs Harbour': 1,
#  'Villaz-St-Pierre': 1,
#  'Saint-Denis Cedex 02': 1,
#  'Madison': 19,
#  'Saint-Jérôme': 1,
#  'Halifax': 5,
#  'Virginia Beach': 1,
#  'Cambridge, Massachusetts': 2,
#  'Sierre': 35,
#  'Kleve': 1,
#  'Rolla': 2,
#  'Bourguillon': 2,
#  'Winterthur TD': 5,
#  'Schwyz': 4,
#  'Woods Hole': 3,
#  'Villeurbanne Cedex': 14,
#  'Lüneburg': 6,
#  'El Paso': 2,
#  'Fällanden': 1,
#  'Hinxton': 1,
#  'Plymouth': 5,
#  'Oberentfelden': 1,
#  'Augsburg': 8,
#  'Dolní Brežany': 1,
#  'Beaucouzé Cédex': 1,
#  'Brugg': 2,
#  'Einsiedeln': 7,
#  'Nancy': 5,
#  'Camperdown': 6,
#  'Morges': 9,
#  'Mendeleevo, Moscow region': 1,
#  'Ames': 3,
#  'Lexington': 7,
#  'Santiago': 6,
#  'Paris Cedes 06': 1,
#  'Kalmar': 1,
#  'Les Diablerets': 1,
#  'Chavannes-sur-Moudon': 1,
#  'La Sagne NE': 5,
#  'Frederiksberg': 7,
#  'Ho Chi Minh City': 3,
#  'Trondheim': 15,
#  'Irkutsk': 2,
#  'Gaithersburg': 7,
#  'Seoul': 18,
#  'Davos 2': 4,
#  'Lima': 4,
#  'Jerusalem': 6,
#  'Kyiv': 22,
#  'Subiaco': 4,
#  'Louisville': 2,
#  'Payerne': 11,
#  'Hamilton': 10,
#  'Brno': 12,
#  'Corvallis': 11,
#  'A Coruña': 1,
#  'Le Bourget du Lac Cedex': 1,
#  'Katowice': 1,
#  'Neuherberg München': 1,
#  'Bern 32': 5,
#  'Richmond, Surrey': 3,
#  'Cardiff, Wales': 2,
#  'Sulgen': 2,
#  'Nidau': 1,
#  'Düdingen': 1,
#  'Worcester': 9,
#  'Zimmerwald': 1,
#  'Boston, MA': 4,
#  'Gelterkinden': 2,
#  'Rosario': 2,
#  'Dublin 15': 1,
#  'Plouzané': 3,
#  'Garmisch': 1,
#  'Triesenberg': 4,
#  'St-Sulpice VD': 7,
#  'Chicoutimi': 1,
#  'Skopje': 31,
#  'Kerch': 1,
#  'Glattbrugg': 1,
#  'B. Velez Sarsfield (5000) Córdoba': 1,
#  'Tartu': 10,
#  'Neuchâtel OFS': 17,
#  'Stirling': 1,
#  'Rijeka': 5,
#  'Salt Lake City': 14,
#  'Siena': 4,
#  'Gland': 1,
#  'Pékin': 1,
#  'Craiova': 2,
#  'Buenos Aires': 9,
#  'Heredia': 2,
#  'Heidelberg  1': 1,
#  'Bologna': 9,
#  'Delley': 2,
#  'Frankfurt a.M.': 4,
#  'Tarragona': 5,
#  'Paris Cédex 13': 1,
#  'Liverpool': 11,
#  'Corsier-sur-Vevey': 1,
#  "Xi'an, Shaanxi": 1,
#  'Ningbo': 1,
#  'Rostock': 9,
#  'Canterbury': 6,
#  'Victoria': 14,
#  'Bari': 4,
#  'Sevilla': 7,
#  'Lausanne 16': 3,
#  'Bucharest-Magurele': 2,
#  'Sils/Segl Maria': 1,
#  'Palaiseau CEDEX': 1,
#  'Le Réduit': 1,
#  'Vancouver, BC': 2,
#  'Genolier': 4,
#  'La Paz': 7,
#  'La Tronche': 3,
#  'Würzburg': 23,
#  'Sion 2': 14,
#  'Freiburg i. Breisgau': 6,
#  'Marseille 20': 1,
#  'Gothenburg': 3,
#  'Quito': 8,
#  'Brig': 20,
#  'Muzzano': 1,
#  'Tours Cedex': 1,
#  'Greenville': 1,
#  'AD Groningen': 1,
#  'Chestnut Hill': 9,
#  'BA Bilthoven': 2,
#  'Dunedin': 7,
#  'Savosa': 1,
#  'Wessling': 4,
#  'Spokane': 1,
#  'Rochester': 8,
#  'Ittigen': 8,
#  'Bradford': 3,
#  'Genova': 8,
#  'Caulfield': 2,
#  'Bobigny cedex (Paris)': 1,
#  'Aberdeen': 8,
#  'Copenhagen N': 1,
#  'Iasi': 15,
#  'Benevento': 1,
#  'Marseille Cedex 09': 3,
#  'Praha 6': 3,
#  'Tulcea': 3,
#  'Belfast': 7,
#  'Udine': 6,
#  'Yuzhno-Sakhlinsk': 1,
#  'Saarbrücken': 15,
#  'Landquart': 7,
#  'Ioannina': 2,
#  'Los Alamos, NM': 1,
#  'Surabaya': 1,
#  'Châtelaine Cases': 1,
#  'Marseille Cedex 9': 5,
#  'Pusan': 1,
#  'Vientiane': 6,
#  'Chavannes-près-Renens': 5,
#  'Bloomington': 6,
#  'Rondebosch, Cape Town': 1,
#  'Grenoble Cédex 9': 2,
#  'Hawthorn': 2,
#  'Bruz': 2,
#  'St-Imier': 6,
#  'Mumbai': 5,
#  'Calcutta': 2,
#  'Vissoie': 1,
#  'Toulouse Cédex': 1,
#  'Paris cedex 16': 1,
#  'Durham NC': 1,
#  'Séville': 1,
#  'Xiamen': 1,
#  'Paris CEDEX 05': 4,
#  'Taipei': 8,
#  'Swansea': 2,
#  'Saint Louis': 2,
#  'Wuhan': 4,
#  'Irvine': 18,
#  'Guangzhou': 2,
#  'Città del Vaticano': 4,
#  'Port-au-Princ': 1,
#  'Saxon': 2,
#  'Lviv': 9,
#  'Lausanne 7': 3,
#  'Durban': 6,
#  'Espoo': 1,
#  'Napoli': 7,
#  'Bellville': 4,
#  'Richmond': 1,
#  'iasi': 6,
#  'Santa Barbara, California': 1,
#  'Kwangju': 1,
#  'New York City': 2,
#  'Andong': 1,
#  'Plan-les-Ouates': 8,
#  'Mont-Saint-Aignan Cedex': 1,
#  'Bern 15': 6,
#  'Sydney ': 4,
#  'Queensland': 1,
#  'Sao Paulo': 7,
#  'GENEVA': 1,
#  'Uetikon am See': 2,
#  'Prag': 6,
#  'Providence': 11,
#  'Abomey-Calavi': 1,
#  'St Louis': 1,
#  'Montréal, QC': 1,
#  'St. Petersburg Stary Peterhof': 1,
#  'Créteil': 3,
#  'Penrith NSW': 1,
#  'Tetovo': 1,
#  'Rez': 1,
#  'Evanston': 16,
#  'Nijmegen': 10,
#  'Thuwal': 6,
#  'Montana': 10,
#  'Chishinau': 2,
#  'Verscio': 4,
#  'Naples': 1,
#  'Abidjan 01': 2,
#  'Fortaleza': 1,
#  'Commune de Kadutu, Bukavu': 1,
#  'Chiba': 3,
#  'Haldenstein': 3,
#  'Leicester': 7,
#  'Tuxtla Gutiérrez': 1,
#  'Cantonments, Accra': 1,
#  'Madagascar': 2,
#  'Québec': 8,
#  'St. Lucia, QLD': 2,
#  'Pietermaritzburg': 1,
#  'Tucson': 12,
#  'Hull': 4,
#  'Gent': 9,
#  'Venice': 2,
#  'Loos': 1,
#  'Moscou': 2,
#  'Vaticano': 2,
#  'Riazzino': 1,
#  'Como': 1,
#  'Cerdanyola del Vallès, Barcelona': 3,
#  'Dublin': 12,
#  'Ascona': 1,
#  'Reading': 5,
#  'Akonolinga': 1,
#  'Golden': 5,
#  'Genève 2': 2,
#  'Austin': 13,
#  'Cartagena': 1,
#  'Alberta': 3,
#  'Tokyo': 26,
#  'Lyon': 11,
#  'Roma RM Lazio': 1,
#  'Sremski Karlovci': 1,
#  'Christchurch': 2,
#  'Palisades': 3,
#  'Triesen': 2,
#  'Oxford, UK': 1,
#  'Aarhus': 6,
#  'Guatemala City': 2,
#  'Cluj – Napoca': 1,
#  'Bern 23': 8,
#  'Missouri': 1,
#  'Cairo': 2,
#  'La Habana': 3,
#  'Tunja': 2,
#  'Lisboa': 13,
#  'Glen Oaks, New York': 1,
#  'Urbino': 2,
#  'Reims': 3,
#  'Bishkek': 16,
#  'Santiago de Compostela': 3,
#  'Shkozet Durrës': 1,
#  'Bron Cédex': 4,
#  'Rotkreuz': 4,
#  'Aveiro': 1,
#  'Wohlen AG 1': 1,
#  'Phoenix': 1,
#  'Rennes Cédex': 2,
#  'Macerata': 2,
#  'Martinsried': 7,
#  'Detroit': 2,
#  'Bucharest Magurele': 3,
#  'Bacau': 1,
#  'Boston, Cambridge Massachusetts': 1,
#  'Novi Sad': 13,
#  'Nashville': 4,
#  'Bowling Green': 1,
#  'Porto': 2,
#  'Santander': 1,
#  'Miskolc-Egyetemvaros': 1,
#  'Nuuk Greenland': 1,
#  'Halle (Saale)': 4,
#  'Zadar': 3,
#  'St Lucia': 4,
#  'Tirana': 19,
#  'Notre Dame': 2,
#  'Poughkeepsie': 1,
#  'Miramar, Playa': 2,
#  'Territet-Veytaux': 1,
#  'Kragujevac': 5,
#  'Lodz': 4,
#  'Uberaba': 1,
#  'São José dos Campos': 1,
#  'Wellington': 9,
#  'Shiraz': 1,
#  'Standord': 1,
#  'Shenzhen': 4,
#  'Shanghai': 12,
#  'Helsingin yliopisto': 1,
#  'BL Delft': 2,
#  'Münsterlingen': 5,
#  'Port Elizabeth, Eastern Cape': 1,
#  'Jouys-en-Josas': 1,
#  'Hyderabad (Andra Pradesh)': 1,
#  'Novosibirsk': 17,
#  'Martin': 1,
#  'Lyon Cedex 7': 3,
#  'Lebanon': 1,
#  'Conthey': 4,
#  'Louvain-La-Neuve': 6,
#  'Collonge-Bellerive': 2,
#  'Marly 1': 3,
#  'Clermont-Ferrand Ced': 3,
#  'Varanasi': 1,
#  'Western Cape': 1,
#  'Brisbane': 15,
#  'Ithaka, NY': 1,
#  'Thônex': 22,
#  'Eindhoven': 6,
#  'Rolle': 2,
#  'Lille Cedex': 3,
#  'Milan': 6,
#  'AD Amsterdam': 1,
#  'San Pedro Montes de Oca': 1,
#  'Colombo': 2,
#  'CC Utrecht': 1,
#  'Mtubatuna': 1,
#  'Romont Caserne': 1,
#  'CG Utrecht': 2,
#  'Castelldefels (Barcelona)': 1,
#  'Vermoim, Maia': 1,
#  'Genève 12': 8,
#  'New Brunswick': 5,
#  'Paris Cedex 06': 2,
#  'Herston, QLD': 1,
#  'Marseille Cédex 15': 1,
#  'Marseille Cédex 9': 1,
#  'Preston': 1,
#  ...}
